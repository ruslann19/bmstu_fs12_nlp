# %%
import pandas as pd

predictions_df = pd.read_csv(
    "./predictions/rubert_linear.tsv",
    sep="\t",
    names=["id", "predicted_rating"],
)
display(predictions_df)
# Out:
#         id  predicted_rating
# 0        0          2.358796
# 1        1          4.566765
# 2        2          1.000000
# 3        3          1.237909
# 4        4          4.041190
# ...    ...               ...
# 5064  5064          1.804462
# 5065  5065          3.677738
# 5066  5066          1.781829
# 5067  5067          1.262709
# 5068  5068          3.925120
#
# [5069 rows x 2 columns]

# %%
from matplotlib import pyplot as plt

predictions_df["predicted_rating"].plot(kind="hist", bins=20, title="predicted_rating")
plt.gca().spines[["top", "right"]].set_visible(False)
